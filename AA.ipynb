# %% [markdown]
# <a href="https://colab.research.google.com/github/mllrosa/pandaas/blob/main/AA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📘 Lista de 30 Exercícios de Pandas — Dataset Empresa

# 1. Mostre as 10 primeiras linhas do dataset.
import pandas as pd
df = pd.read_csv('empresa.csv')
df.head(10)
# Out:
#    id      nome       setor  salario  tempo_empresa_anos          cidade
# 0   1    Carlos  Financeiro     3500                   1       São Paulo
# 1   2       Ana          RH     4200                   3  Rio de Janeiro
# 2   3     Bruno          TI     5000                   5  Belo Horizonte
# 3   4     Maria   Marketing     3800                   2        Curitiba
# 4   5      João      Vendas     4500                   4    Porto Alegre
# 5   6     Paula  Financeiro     3500                   1       São Paulo
# 6   7   Ricardo          RH     4200                   3  Rio de Janeiro
# 7   8  Fernanda          TI     5000                   5  Belo Horizonte
# 8   9     Tiago   Marketing     3800                   2        Curitiba
# 9  10     Julia      Vendas     4500                   4    Porto Alegre

# %%
# 2. Exiba as 15 últimas linhas do dataset.
import pandas as pd
df = pd.read_csv('empresa.csv')
df.tail(15)
# Out:
#     id      nome       setor  salario  tempo_empresa_anos          cidade
# 35  36     Paula  Financeiro     3500                   1       São Paulo
# 36  37   Ricardo          RH     4200                   3  Rio de Janeiro
# 37  38  Fernanda          TI     5000                   5  Belo Horizonte
# 38  39     Tiago   Marketing     3800                   2        Curitiba
# 39  40     Julia      Vendas     4500                   4    Porto Alegre
# 40  41    Carlos  Financeiro     3500                   1       São Paulo
# 41  42       Ana          RH     4200                   3  Rio de Janeiro
# 42  43     Bruno          TI     5000                   5  Belo Horizonte
# 43  44     Maria   Marketing     3800                   2        Curitiba
# 44  45      João      Vendas     4500                   4    Porto Alegre
# 45  46     Paula  Financeiro     3500                   1       São Paulo
# 46  47   Ricardo          RH     4200                   3  Rio de Janeiro
# ...

# %%
# 3. Mostre o nome das colunas da tabela.
import pandas as pd
df = pd.read_csv('empresa.csv')
df.columns
# Out:
# Index(['id', 'nome', 'setor', 'salario', 'tempo_empresa_anos', 'cidade'], dtype='object')

# %%
# 4. Exiba informações gerais do dataset (tipos de dados, não nulos, etc.).
import pandas as pd
df = pd.read_csv('empresa.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  50 non-null     int64
#  1   nome                50 non-null     object
#  2   setor               50 non-null     object
#  3   salario             50 non-null     int64
#  4   tempo_empresa_anos  50 non-null     int64
#  5   cidade              50 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 2.5+ KB

# %%
# 5. Mostre estatísticas descritivas das colunas numéricas.
import pandas as pd
df = pd.read_csv('empresa.csv')
df.describe()
# Out:
#              id      salario  tempo_empresa_anos
# count  50.00000    50.000000           50.000000
# mean   25.50000  4200.000000            3.000000
# std    14.57738   530.690732            1.428571
# min     1.00000  3500.000000            1.000000
# 25%    13.25000  3800.000000            2.000000
# 50%    25.50000  4200.000000            3.000000
# 75%    37.75000  4500.000000            4.000000
# max    50.00000  5000.000000            5.000000

# %%
# 6. Filtre todas as linhas onde o nome é **"Carlos"**.
import pandas as pd
df = pd.read_csv('empresa.csv')
df[df['nome'] == 'Carlos']
# Out:
#     id    nome       setor  salario  tempo_empresa_anos     cidade
# 0    1  Carlos  Financeiro     3500                   1  São Paulo
# 10  11  Carlos  Financeiro     3500                   1  São Paulo
# 20  21  Carlos  Financeiro     3500                   1  São Paulo
# 30  31  Carlos  Financeiro     3500                   1  São Paulo
# 40  41  Carlos  Financeiro     3500                   1  São Paulo

# %%
# 7. Filtre as pessoas que trabalham no setor de **TI**.
import pandas as pd
df = pd.read_csv('empresa.csv')
df[df['setor'] == 'TI']
# Out:
#     id      nome setor  salario  tempo_empresa_anos          cidade
# 2    3     Bruno    TI     5000                   5  Belo Horizonte
# 7    8  Fernanda    TI     5000                   5  Belo Horizonte
# 12  13     Bruno    TI     5000                   5  Belo Horizonte
# 17  18  Fernanda    TI     5000                   5  Belo Horizonte
# 22  23     Bruno    TI     5000                   5  Belo Horizonte
# 27  28  Fernanda    TI     5000                   5  Belo Horizonte
# 32  33     Bruno    TI     5000                   5  Belo Horizonte
# 37  38  Fernanda    TI     5000                   5  Belo Horizonte
# 42  43     Bruno    TI     5000                   5  Belo Horizonte
# 47  48  Fernanda    TI     5000                   5  Belo Horizonte

# %%
# 8. Mostre todos os funcionários com salário maior que 4000.
import pandas as pd
df = pd.read_csv('empresa.csv')
df[df['salario'] > 4000]
# Out:
#     id      nome   setor  salario  tempo_empresa_anos          cidade
# 1    2       Ana      RH     4200                   3  Rio de Janeiro
# 2    3     Bruno      TI     5000                   5  Belo Horizonte
# 4    5      João  Vendas     4500                   4    Porto Alegre
# 6    7   Ricardo      RH     4200                   3  Rio de Janeiro
# 7    8  Fernanda      TI     5000                   5  Belo Horizonte
# 9   10     Julia  Vendas     4500                   4    Porto Alegre
# 11  12       Ana      RH     4200                   3  Rio de Janeiro
# 12  13     Bruno      TI     5000                   5  Belo Horizonte
# 14  15      João  Vendas     4500                   4    Porto Alegre
# 16  17   Ricardo      RH     4200                   3  Rio de Janeiro
# 17  18  Fernanda      TI     5000                   5  Belo Horizonte
# 19  20     Julia  Vendas     4500                   4    Porto Alegre
# ...

# %%
# 9. Mostre apenas as colunas **nome** e **salario**.
import pandas as pd
df = pd.read_csv('empresa.csv')
df[['nome','salario']]
# Out:
#         nome  salario
# 0     Carlos     3500
# 1        Ana     4200
# 2      Bruno     5000
# 3      Maria     3800
# 4       João     4500
# 5      Paula     3500
# 6    Ricardo     4200
# 7   Fernanda     5000
# 8      Tiago     3800
# 9      Julia     4500
# 10    Carlos     3500
# 11       Ana     4200
# 12     Bruno     5000
# 13     Maria     3800
# 14      João     4500
# 15     Paula     3500
# 16   Ricardo     4200
# 17  Fernanda     5000
# 18     Tiago     3800
# 19     Julia     4500
# 20    Carlos     3500
# 21       Ana     4200
# 22     Bruno     5000
# 23     Maria     3800
# 24      João     4500
# 25     Paula     3500
# 26   Ricardo     4200
# 27  Fernanda     5000
# 28     Tiago     3800
# 29     Julia     4500
# 30    Carlos     3500
# 31       Ana     4200
# 32     Bruno     5000
# 33     Maria     3800
# 34      João     4500
# 35     Paula     3500
# 36   Ricardo     4200
# 37  Fernanda     5000
# 38     Tiago     3800
# 39     Julia     4500
# ...

# %%
# 10. Ordene o dataset pelo salário em ordem crescente.
import pandas as pd
df = pd.read_csv('empresa.csv')
df.sort_values('salario')
# Out:
#     id      nome       setor  salario  tempo_empresa_anos          cidade
# 0    1    Carlos  Financeiro     3500                   1       São Paulo
# 5    6     Paula  Financeiro     3500                   1       São Paulo
# 15  16     Paula  Financeiro     3500                   1       São Paulo
# 10  11    Carlos  Financeiro     3500                   1       São Paulo
# 25  26     Paula  Financeiro     3500                   1       São Paulo
# 30  31    Carlos  Financeiro     3500                   1       São Paulo
# 20  21    Carlos  Financeiro     3500                   1       São Paulo
# 35  36     Paula  Financeiro     3500                   1       São Paulo
# 40  41    Carlos  Financeiro     3500                   1       São Paulo
# 45  46     Paula  Financeiro     3500                   1       São Paulo
# 18  19     Tiago   Marketing     3800                   2        Curitiba
# 23  24     Maria   Marketing     3800                   2        Curitiba
# ...

# %%
# 11. Ordene o dataset pelo salário em ordem decrescente.
import pandas as pd
df = pd.read_csv('empresa.csv')
df.sort_values('salario',ascending=False)
# Out:
#     id      nome       setor  salario  tempo_empresa_anos          cidade
# 7    8  Fernanda          TI     5000                   5  Belo Horizonte
# 2    3     Bruno          TI     5000                   5  Belo Horizonte
# 17  18  Fernanda          TI     5000                   5  Belo Horizonte
# 12  13     Bruno          TI     5000                   5  Belo Horizonte
# 47  48  Fernanda          TI     5000                   5  Belo Horizonte
# 42  43     Bruno          TI     5000                   5  Belo Horizonte
# 37  38  Fernanda          TI     5000                   5  Belo Horizonte
# 32  33     Bruno          TI     5000                   5  Belo Horizonte
# 27  28  Fernanda          TI     5000                   5  Belo Horizonte
# 22  23     Bruno          TI     5000                   5  Belo Horizonte
# 19  20     Julia      Vendas     4500                   4    Porto Alegre
# 24  25      João      Vendas     4500                   4    Porto Alegre
# ...

# %%
# 12. Conte quantos funcionários existem por setor.
import pandas as pd
df = pd.read_csv('empresa.csv')
setores = df.groupby('setor').size()
setores
# Out:
# setor
# Financeiro    10
# Marketing     10
# RH            10
# TI            10
# Vendas        10
# dtype: int64

# %%
# 13. Calcule a média salarial de todos os funcionários.
import pandas as pd
df = pd.read_csv('empresa.csv')
df = df['salario'].mean()
df
# Out:
# np.float64(4200.0)

# %%
# 14. Encontre o maior salário registrado.
import pandas as pd
df = pd.read_csv('empresa.csv')
df['salario'].max()
# Out:
# 5000

# %%
# 15. Encontre o menor salário registrado.
import pandas as pd
df = pd.read_csv('empresa.csv')
df['salario'].min()
# Out:
# 3500

# %%
# 16. Filtre quem tem mais de 3 anos de empresa.
import pandas as pd
df = pd.read_csv('empresa.csv')
df[df['tempo_empresa_anos'] > 3]
# Out:
#     id      nome   setor  salario  tempo_empresa_anos          cidade
# 2    3     Bruno      TI     5000                   5  Belo Horizonte
# 4    5      João  Vendas     4500                   4    Porto Alegre
# 7    8  Fernanda      TI     5000                   5  Belo Horizonte
# 9   10     Julia  Vendas     4500                   4    Porto Alegre
# 12  13     Bruno      TI     5000                   5  Belo Horizonte
# 14  15      João  Vendas     4500                   4    Porto Alegre
# 17  18  Fernanda      TI     5000                   5  Belo Horizonte
# 19  20     Julia  Vendas     4500                   4    Porto Alegre
# 22  23     Bruno      TI     5000                   5  Belo Horizonte
# 24  25      João  Vendas     4500                   4    Porto Alegre
# 27  28  Fernanda      TI     5000                   5  Belo Horizonte
# 29  30     Julia  Vendas     4500                   4    Porto Alegre
# ...

# %%
# 17. Mostre todos os funcionários da cidade de **São Paulo**.
import pandas as pd
df = pd.read_csv('empresa.csv')
df[df['cidade'] == 'São Paulo']
# Out:
#     id    nome       setor  salario  tempo_empresa_anos     cidade
# 0    1  Carlos  Financeiro     3500                   1  São Paulo
# 5    6   Paula  Financeiro     3500                   1  São Paulo
# 10  11  Carlos  Financeiro     3500                   1  São Paulo
# 15  16   Paula  Financeiro     3500                   1  São Paulo
# 20  21  Carlos  Financeiro     3500                   1  São Paulo
# 25  26   Paula  Financeiro     3500                   1  São Paulo
# 30  31  Carlos  Financeiro     3500                   1  São Paulo
# 35  36   Paula  Financeiro     3500                   1  São Paulo
# 40  41  Carlos  Financeiro     3500                   1  São Paulo
# 45  46   Paula  Financeiro     3500                   1  São Paulo

# %%
# 18. Agrupe por setor e mostre a média dos salários.
import pandas as pd
df = pd.read_csv('empresa.csv')
df = df.groupby('setor')['salario'].mean()
df
# Out:
# setor
# Financeiro    3500.0
# Marketing     3800.0
# RH            4200.0
# TI            5000.0
# Vendas        4500.0
# Name: salario, dtype: float64

# %%
# 19. Mostre os funcionários cujo nome começa com a letra **"J"**.
import pandas as pd
df = pd.read_csv('empresa.csv')
j= df[df['nome'].str.startswith('J')]
j
# Out:
#     id   nome   setor  salario  tempo_empresa_anos        cidade
# 4    5   João  Vendas     4500                   4  Porto Alegre
# 9   10  Julia  Vendas     4500                   4  Porto Alegre
# 14  15   João  Vendas     4500                   4  Porto Alegre
# 19  20  Julia  Vendas     4500                   4  Porto Alegre
# 24  25   João  Vendas     4500                   4  Porto Alegre
# 29  30  Julia  Vendas     4500                   4  Porto Alegre
# 34  35   João  Vendas     4500                   4  Porto Alegre
# 39  40  Julia  Vendas     4500                   4  Porto Alegre
# 44  45   João  Vendas     4500                   4  Porto Alegre
# 49  50  Julia  Vendas     4500                   4  Porto Alegre

# %%
# 20. Conte quantas vezes cada cidade aparece no dataset.
import pandas as pd
df = pd.read_csv('empresa.csv')
contagem_setores = df.groupby('cidade').size()
contagem_setores
# Out:
# cidade
# Belo Horizonte    10
# Curitiba          10
# Porto Alegre      10
# Rio de Janeiro    10
# São Paulo         10
# dtype: int64

# %%
# 21. Adicione uma nova coluna chamada **"bonus"** com 10% do salário.
import pandas as pd
df['bonus'] = df['salario'] * 0.10
df
# Out:
#     id      nome       setor  salario  tempo_empresa_anos          cidade  \
# 0    1    Carlos  Financeiro     3500                   1       São Paulo
# 1    2       Ana          RH     4200                   3  Rio de Janeiro
# 2    3     Bruno          TI     5000                   5  Belo Horizonte
# 3    4     Maria   Marketing     3800                   2        Curitiba
# 4    5      João      Vendas     4500                   4    Porto Alegre
# 5    6     Paula  Financeiro     3500                   1       São Paulo
# 6    7   Ricardo          RH     4200                   3  Rio de Janeiro
# 7    8  Fernanda          TI     5000                   5  Belo Horizonte
# 8    9     Tiago   Marketing     3800                   2        Curitiba
# 9   10     Julia      Vendas     4500                   4    Porto Alegre
# 10  11    Carlos  Financeiro     3500                   1       São Paulo
# 11  12       Ana          RH     4200                   3  Rio de Janeiro
# ...

# %%
# 22. Mostre apenas funcionários cujo salário seja entre 3500 e 4500.
import pandas as pd
df = pd.read_csv('empresa.csv')
df = df[(df['salario'] >= 3500) & (df['salario'] <= 4500)]
df
# Out:
#     id     nome       setor  salario  tempo_empresa_anos          cidade
# 0    1   Carlos  Financeiro     3500                   1       São Paulo
# 1    2      Ana          RH     4200                   3  Rio de Janeiro
# 3    4    Maria   Marketing     3800                   2        Curitiba
# 4    5     João      Vendas     4500                   4    Porto Alegre
# 5    6    Paula  Financeiro     3500                   1       São Paulo
# 6    7  Ricardo          RH     4200                   3  Rio de Janeiro
# 8    9    Tiago   Marketing     3800                   2        Curitiba
# 9   10    Julia      Vendas     4500                   4    Porto Alegre
# 10  11   Carlos  Financeiro     3500                   1       São Paulo
# 11  12      Ana          RH     4200                   3  Rio de Janeiro
# 13  14    Maria   Marketing     3800                   2        Curitiba
# 14  15     João      Vendas     4500                   4    Porto Alegre
# ...

# %%
# 23. Remova a coluna **cidade** do dataframe.
import pandas as pd
df = pd.read_csv('empresa.csv')
df = df.drop(columns=['cidade'])
df
# Out:
#     id      nome       setor  salario  tempo_empresa_anos
# 0    1    Carlos  Financeiro     3500                   1
# 1    2       Ana          RH     4200                   3
# 2    3     Bruno          TI     5000                   5
# 3    4     Maria   Marketing     3800                   2
# 4    5      João      Vendas     4500                   4
# 5    6     Paula  Financeiro     3500                   1
# 6    7   Ricardo          RH     4200                   3
# 7    8  Fernanda          TI     5000                   5
# 8    9     Tiago   Marketing     3800                   2
# 9   10     Julia      Vendas     4500                   4
# 10  11    Carlos  Financeiro     3500                   1
# 11  12       Ana          RH     4200                   3
# 12  13     Bruno          TI     5000                   5
# 13  14     Maria   Marketing     3800                   2
# 14  15      João      Vendas     4500                   4
# ...

# %%
# 24. Verifique se existe algum valor nulo no dataset.
import pandas as pd
df = pd.read_csv('empresa.csv')
df.isnull()
# Out:
#        id   nome  setor  salario  tempo_empresa_anos  cidade
# 0   False  False  False    False               False   False
# 1   False  False  False    False               False   False
# 2   False  False  False    False               False   False
# 3   False  False  False    False               False   False
# 4   False  False  False    False               False   False
# 5   False  False  False    False               False   False
# 6   False  False  False    False               False   False
# 7   False  False  False    False               False   False
# 8   False  False  False    False               False   False
# 9   False  False  False    False               False   False
# 10  False  False  False    False               False   False
# 11  False  False  False    False               False   False
# 12  False  False  False    False               False   False
# 13  False  False  False    False               False   False
# ...

# %%
# 25. Mostre os funcionários com salário igual a 5000.
import pandas as pd
df = pd.read_csv('empresa.csv')
df[df['salario'] == 5000]
# Out:
#     id      nome setor  salario  tempo_empresa_anos          cidade
# 2    3     Bruno    TI     5000                   5  Belo Horizonte
# 7    8  Fernanda    TI     5000                   5  Belo Horizonte
# 12  13     Bruno    TI     5000                   5  Belo Horizonte
# 17  18  Fernanda    TI     5000                   5  Belo Horizonte
# 22  23     Bruno    TI     5000                   5  Belo Horizonte
# 27  28  Fernanda    TI     5000                   5  Belo Horizonte
# 32  33     Bruno    TI     5000                   5  Belo Horizonte
# 37  38  Fernanda    TI     5000                   5  Belo Horizonte
# 42  43     Bruno    TI     5000                   5  Belo Horizonte
# 47  48  Fernanda    TI     5000                   5  Belo Horizonte

# %%
# 26. Crie um dataframe somente com trabalhadores do setor **Marketing**.
import pandas as pd
df = pd.read_csv('empresa.csv')
df[df['setor'] == 'Marketing']
# Out:
#     id   nome      setor  salario  tempo_empresa_anos    cidade
# 3    4  Maria  Marketing     3800                   2  Curitiba
# 8    9  Tiago  Marketing     3800                   2  Curitiba
# 13  14  Maria  Marketing     3800                   2  Curitiba
# 18  19  Tiago  Marketing     3800                   2  Curitiba
# 23  24  Maria  Marketing     3800                   2  Curitiba
# 28  29  Tiago  Marketing     3800                   2  Curitiba
# 33  34  Maria  Marketing     3800                   2  Curitiba
# 38  39  Tiago  Marketing     3800                   2  Curitiba
# 43  44  Maria  Marketing     3800                   2  Curitiba
# 48  49  Tiago  Marketing     3800                   2  Curitiba

# %%
# 27. Renomeie a coluna **tempo_empresa_anos** para **anos_empresa**.
import pandas as pd
df = pd.read_csv('empresa.csv')
df = df.rename(columns={'tempo_empresa_anos': 'anos_empresa'})
df
# Out:
#     id      nome       setor  salario  anos_empresa          cidade
# 0    1    Carlos  Financeiro     3500             1       São Paulo
# 1    2       Ana          RH     4200             3  Rio de Janeiro
# 2    3     Bruno          TI     5000             5  Belo Horizonte
# 3    4     Maria   Marketing     3800             2        Curitiba
# 4    5      João      Vendas     4500             4    Porto Alegre
# 5    6     Paula  Financeiro     3500             1       São Paulo
# 6    7   Ricardo          RH     4200             3  Rio de Janeiro
# 7    8  Fernanda          TI     5000             5  Belo Horizonte
# 8    9     Tiago   Marketing     3800             2        Curitiba
# 9   10     Julia      Vendas     4500             4    Porto Alegre
# 10  11    Carlos  Financeiro     3500             1       São Paulo
# 11  12       Ana          RH     4200             3  Rio de Janeiro
# 12  13     Bruno          TI     5000             5  Belo Horizonte
# ...

# %%
# 28. Mostre o salário médio agrupado por cidade.
import pandas as pd
df = pd.read_csv('empresa.csv')
df = df.groupby('cidade')['salario'].mean()
df
# Out:
# cidade
# Belo Horizonte    5000.0
# Curitiba          3800.0
# Porto Alegre      4500.0
# Rio de Janeiro    4200.0
# São Paulo         3500.0
# Name: salario, dtype: float64

# %%
# 29. Selecione aleatoriamente 5 linhas do dataset.
import pandas as pd
df = pd.read_csv('empresa.csv')
df = df.sample(5)
df
# Out:
#     id   nome      setor  salario  tempo_empresa_anos          cidade
# 38  39  Tiago  Marketing     3800                   2        Curitiba
# 2    3  Bruno         TI     5000                   5  Belo Horizonte
# 29  30  Julia     Vendas     4500                   4    Porto Alegre
# 43  44  Maria  Marketing     3800                   2        Curitiba
# 4    5   João     Vendas     4500                   4    Porto Alegre

# %%
# 30. Crie um filtro para mostrar somente funcionários que não são do setor de RH.
import pandas as pd
df = pd.read_csv('empresa.csv')
df[df['setor'] != 'RH']
# Out:
#     id      nome       setor  salario  tempo_empresa_anos          cidade
# 0    1    Carlos  Financeiro     3500                   1       São Paulo
# 2    3     Bruno          TI     5000                   5  Belo Horizonte
# 3    4     Maria   Marketing     3800                   2        Curitiba
# 4    5      João      Vendas     4500                   4    Porto Alegre
# 5    6     Paula  Financeiro     3500                   1       São Paulo
# 7    8  Fernanda          TI     5000                   5  Belo Horizonte
# 8    9     Tiago   Marketing     3800                   2        Curitiba
# 9   10     Julia      Vendas     4500                   4    Porto Alegre
# 10  11    Carlos  Financeiro     3500                   1       São Paulo
# 12  13     Bruno          TI     5000                   5  Belo Horizonte
# 13  14     Maria   Marketing     3800                   2        Curitiba
# 14  15      João      Vendas     4500                   4    Porto Alegre
# ...
